# %%
import matplotlib.font_manager
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
plt.rc('font', family='NanumGothic')
mpl.rcParams['axes.unicode_minus'] = False

# %%
import openpyxl
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
df1 = pd.read_excel('/Users/SAMSUNG/화물차 사고 저감 방안/2021년도 차종별 교통사고.xlsx')
df1
# Out:
#              차종  사고건수(건)  사망자수(명)  부상자수(명)
# 0             계   203130     2916   291608
# 1           승용차   132440     1348   195686
# 2           승합차     9923      146    14510
# 3           화물차    26081      687    38052
# 4           특수차     1228       39     1847
# 5           이륜차    18375      397    23846
# 6   사륜오토바이(ATV)      249       23      279
# 7      원동기장치자전거     1974       39     2492
# 8           자전거     5509       70     5999
# 9   개인형이동수단(PM)     1735       19     1901
# 10         건설기계     2510       79     3599
# 11          농기계      364       62      394
# 12           기타      149        6      170
# 13           불명     2593        1     2833

# %%
df2 = df1.transpose()
df2
# Out:
#              0       1      2      3     4      5            6         7   \
# 차종            계     승용차    승합차    화물차   특수차    이륜차  사륜오토바이(ATV)  원동기장치자전거
# 사고건수(건)  203130  132440   9923  26081  1228  18375          249      1974
# 사망자수(명)    2916    1348    146    687    39    397           23        39
# 부상자수(명)  291608  195686  14510  38052  1847  23846          279      2492
#
#            8            9     10   11   12    13
# 차종        자전거  개인형이동수단(PM)  건설기계  농기계   기타    불명
# 사고건수(건)  5509         1735  2510  364  149  2593
# 사망자수(명)    70           19    79   62    6     1
# 부상자수(명)  5999         1901  3599  394  170  2833

# %%
df3 = df2.rename(columns=df2.iloc[0])
df3
# Out:
#               계     승용차    승합차    화물차   특수차    이륜차  사륜오토바이(ATV)  원동기장치자전거  \
# 차종            계     승용차    승합차    화물차   특수차    이륜차  사륜오토바이(ATV)  원동기장치자전거
# 사고건수(건)  203130  132440   9923  26081  1228  18375          249      1974
# 사망자수(명)    2916    1348    146    687    39    397           23        39
# 부상자수(명)  291608  195686  14510  38052  1847  23846          279      2492
#
#           자전거  개인형이동수단(PM)  건설기계  농기계   기타    불명
# 차종        자전거  개인형이동수단(PM)  건설기계  농기계   기타    불명
# 사고건수(건)  5509         1735  2510  364  149  2593
# 사망자수(명)    70           19    79   62    6     1
# 부상자수(명)  5999         1901  3599  394  170  2833

# %%
df3.drop(['계'], axis=1, inplace = True)
df3
# Out:
#             승용차    승합차    화물차   특수차    이륜차  사륜오토바이(ATV)  원동기장치자전거   자전거  \
# 차종          승용차    승합차    화물차   특수차    이륜차  사륜오토바이(ATV)  원동기장치자전거   자전거
# 사고건수(건)  132440   9923  26081  1228  18375          249      1974  5509
# 사망자수(명)    1348    146    687    39    397           23        39    70
# 부상자수(명)  195686  14510  38052  1847  23846          279      2492  5999
#
#          개인형이동수단(PM)  건설기계  농기계   기타    불명
# 차종       개인형이동수단(PM)  건설기계  농기계   기타    불명
# 사고건수(건)         1735  2510  364  149  2593
# 사망자수(명)           19    79   62    6     1
# 부상자수(명)         1901  3599  394  170  2833

# %%
df4 = df3.iloc[1:,]
df4
# Out:
#             승용차    승합차    화물차   특수차    이륜차 사륜오토바이(ATV) 원동기장치자전거   자전거  \
# 사고건수(건)  132440   9923  26081  1228  18375         249     1974  5509
# 사망자수(명)    1348    146    687    39    397          23       39    70
# 부상자수(명)  195686  14510  38052  1847  23846         279     2492  5999
#
#         개인형이동수단(PM)  건설기계  농기계   기타    불명
# 사고건수(건)        1735  2510  364  149  2593
# 사망자수(명)          19    79   62    6     1
# 부상자수(명)        1901  3599  394  170  2833

# %%
df5 = df4.transpose()
df5
# Out:
#             사고건수(건) 사망자수(명) 부상자수(명)
# 승용차          132440    1348  195686
# 승합차            9923     146   14510
# 화물차           26081     687   38052
# 특수차            1228      39    1847
# 이륜차           18375     397   23846
# 사륜오토바이(ATV)     249      23     279
# 원동기장치자전거       1974      39    2492
# 자전거            5509      70    5999
# 개인형이동수단(PM)    1735      19    1901
# 건설기계           2510      79    3599
# 농기계             364      62     394
# 기타              149       6     170
# 불명             2593       1    2833

# %%
df6 = df5.reset_index().rename(columns={'index': '차종'})
df6
# Out:
#              차종 사고건수(건) 사망자수(명) 부상자수(명)
# 0           승용차  132440    1348  195686
# 1           승합차    9923     146   14510
# 2           화물차   26081     687   38052
# 3           특수차    1228      39    1847
# 4           이륜차   18375     397   23846
# 5   사륜오토바이(ATV)     249      23     279
# 6      원동기장치자전거    1974      39    2492
# 7           자전거    5509      70    5999
# 8   개인형이동수단(PM)    1735      19    1901
# 9          건설기계    2510      79    3599
# 10          농기계     364      62     394
# 11           기타     149       6     170
# 12           불명    2593       1    2833

# %%
plt.figure(figsize=(22,10))
plt.bar(df6["차종"], df6["사고건수(건)"],width=0.5)
plt.title('차종별 사고건수(건)')
plt.show()

# %%
plt.figure(figsize=(22,10))
plt.bar(df6["차종"], df6["사망자수(명)"],width=0.5)
plt.title('차종별 사망자수(명)')
plt.show()

# %%
plt.figure(figsize=(22,10))
plt.bar(df6["차종"], df6["부상자수(명)"],width=0.5)
plt.title('차종별 부상자수(명)')
plt.show()
