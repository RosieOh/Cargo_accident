# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
from matplotlib import rc 
rc('font', family='AppleGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_excel('2020년 화물차 기상상태별 교통사고.xls')
df1
# Out:
#   기상상태   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0   맑음  23786     2      0   1479   569    2.39
# 1   흐림    958     0      0     61    53    5.53
# 2    비   2011     1      0    133    85    4.23
# 3   안개     44     0      0      7     5   11.36
# 4    눈     79     1      0      9     4    5.06
# 5   기타    185     0      0     14     5    2.70
# 6   합계  27063     4      0   1703   721     NaN

# %%
df1 = df1.fillna(0)
df1
# Out:
#   기상상태   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0   맑음  23786     2      0   1479   569    2.39
# 1   흐림    958     0      0     61    53    5.53
# 2    비   2011     1      0    133    85    4.23
# 3   안개     44     0      0      7     5   11.36
# 4    눈     79     1      0      9     4    5.06
# 5   기타    185     0      0     14     5    2.70
# 6   합계  27063     4      0   1703   721    0.00

# %%
df2 = df1[['화물(건)', '사망자수']]
df2
# Out:
#    화물(건)  사망자수
# 0   1479   569
# 1     61    53
# 2    133    85
# 3      7     5
# 4      9     4
# 5     14     5
# 6   1703   721

# %%
df_1 = df1["기상상태"]
df_2 = df1["발생건수"]
df_3 = df1["대형사고"]
df_4 = df1["화물(건)"]
df_5 = df1["사망자수"]
df_6 = df1["치사율(%)"]

# %%
plt.bar(df_1, df_2)
plt.title('발생건수')
plt.show()
# Out:
#   File "/var/folders/h1/q58t7z655y9fl5rtbw1vkzv00000gn/T/ipykernel_86764/3889426628.py", line 3
#     plt.show()plt.bar(df_1, df_3)
#                 ^
# SyntaxError: invalid syntax

# %%
plt.bar(df_1, df_3)
plt.title('대형사고')
plt.show()

# %%
plt.bar(df_1, df_4)
plt.title('화물(건)')
plt.show()

# %%
plt.bar(df_1, df_5)
plt.title('사망자수')
plt.show()

# %%
plt.bar(df_1, df_6)
plt.title('치사율(%)')
plt.show()

# %%
plt.plot(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
p_1 = sns.distplot(df_2)
p_1.set_title("화물차 사고 발생 건수")
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, '화물차 사고 발생 건수')

# %%
sns.distplot(df_3)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='대형사고', ylabel='Density'>

# %%
sns.distplot(df_4)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='화물(건)', ylabel='Density'>

# %%
sns.distplot(df_5)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='사망자수', ylabel='Density'>

# %%
sns.distplot(df_6)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>

# %%
p = sns.lineplot(data = df2)
p.set_title("화물차 사망자 수 비교")
# Out:
# Text(0.5, 1.0, '화물차 사망자 수 비교')

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(20,20))

sns.distplot(df1['발생건수'], ax=ax[0,0])
sns.distplot(df1['대형사고'], ax=ax[0,1])
sns.distplot(df1['사망자수'], ax=ax[1,0])
sns.distplot(df1['치사율(%)'], ax=ax[1,1])
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>

# %%
plt.plot(df_1, df_4, 'o-', color='#C8C8FF', label='line01')
plt.plot(df_1, df_5, '^--g', linewidth=5, markeredgewidth=5, label='line02')

plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.title('사망자수/치사율(%)')

plt.show()
