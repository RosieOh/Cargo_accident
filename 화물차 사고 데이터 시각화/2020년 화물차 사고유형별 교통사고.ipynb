# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc 
rc('font', family='AppleGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_excel('2020년 화물차 사고유형별 교통사고.xls')
df1
# Out:
#           사고유형   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0          횡단중   1600     0      0    182   120    7.50
# 1        차도통행중    502     0      0     33    48    9.56
# 2   길가장자리구역통행중    284     0      0     23    13    4.58
# 3        보도통행중    226     0      0     22     8    3.54
# 4      차대사람-기타   1858     0      0    172    80    4.31
# 5         정면충돌    949     0      0     52    30    3.16
# 6       측면직각충돌   9465     1      0    481    84    0.89
# 7      추돌(진행중)   5277     1      0    385   148    2.80
# 8        후진중추돌    663     0      0     19     3    0.45
# 9       차대차-기타   5367     1      0    293    68    1.27
# 10       공작물추돌    477     0      0     18    52   10.90
# 11   도로외이탈(추락)    109     0      0      7    21   19.27
# 12   도로외이탈(기타)     45     0      0      4     6   13.33
# 13      주차차량추돌      2     0      0      0     1   50.00
# 14          전도     85     1      0      4    14   16.47
# 15          전복     15     0      0      1     5   33.33
# 16     차량단독-기타    139     0      0      7    20   14.39
# 17          합계  27063     4      0   1703   721     NaN

# %%
df1 = df1.fillna(0)
df1
# Out:
#           사고유형   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0          횡단중   1600     0      0    182   120    7.50
# 1        차도통행중    502     0      0     33    48    9.56
# 2   길가장자리구역통행중    284     0      0     23    13    4.58
# 3        보도통행중    226     0      0     22     8    3.54
# 4      차대사람-기타   1858     0      0    172    80    4.31
# 5         정면충돌    949     0      0     52    30    3.16
# 6       측면직각충돌   9465     1      0    481    84    0.89
# 7      추돌(진행중)   5277     1      0    385   148    2.80
# 8        후진중추돌    663     0      0     19     3    0.45
# 9       차대차-기타   5367     1      0    293    68    1.27
# 10       공작물추돌    477     0      0     18    52   10.90
# 11   도로외이탈(추락)    109     0      0      7    21   19.27
# 12   도로외이탈(기타)     45     0      0      4     6   13.33
# 13      주차차량추돌      2     0      0      0     1   50.00
# 14          전도     85     1      0      4    14   16.47
# 15          전복     15     0      0      1     5   33.33
# 16     차량단독-기타    139     0      0      7    20   14.39
# 17          합계  27063     4      0   1703   721    0.00

# %%
df2 = df1[['화물(건)', '사망자수']]
df2
# Out:
#     화물(건)  사망자수
# 0     182   120
# 1      33    48
# 2      23    13
# 3      22     8
# 4     172    80
# 5      52    30
# 6     481    84
# 7     385   148
# 8      19     3
# 9     293    68
# 10     18    52
# 11      7    21
# 12      4     6
# 13      0     1
# 14      4    14
# 15      1     5
# 16      7    20
# 17   1703   721

# %%
df_1 = df1["사고유형"]
df_2 = df1["발생건수"]
df_3 = df1["대형사고"]
df_4 = df1["화물(건)"]
df_5 = df1["사망자수"]
df_6 = df1["치사율(%)"]

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_3)
plt.title('대형사고')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_4)
plt.title('화물(건)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_5)
plt.title('사망자수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_6)
plt.title('치사량(%)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
p_1 = sns.distplot(df_2)
p_1.set_title("화물차 사고 발생 건수")
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, '화물차 사고 발생 건수')

# %%
sns.distplot(df_3)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='대형사고', ylabel='Density'>

# %%
sns.distplot(df_4)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='화물(건)', ylabel='Density'>

# %%
sns.distplot(df_5)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='사망자수', ylabel='Density'>

# %%
sns.distplot(df_6)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>

# %%
p = sns.lineplot(data = df2)
p.set_title("화물차 사망자 수 비교")
# Out:
# Text(0.5, 1.0, '화물차 사망자 수 비교')

# %%
fig, ax = plt.subplots(ncols=2, nrows=3, figsize=(20,20))

sns.distplot(df1['발생건수'], ax=ax[0,0])
sns.distplot(df1['대형사고'], ax=ax[0,1])
sns.distplot(df1['사망자수'], ax=ax[1,0])
sns.distplot(df1['치사율(%)'], ax=ax[1,1])
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>
