# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc 
rc('font', family='AppleGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_excel('2020년 화물차 도로형태별 교통사고.xls')
df1
# Out:
#          도로형태   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0        교차로안   7744     1      0    430   146    1.89
# 1       교차로부근   4004     0      0    206    80    2.00
# 2          터널    159     1      0     24     7    4.40
# 3          교량    237     0      0     27    13    5.49
# 4     기타(단일로)  12165     2      0    804   389    3.20
# 5       고가도로위     80     0      0      3     4    5.00
# 6   지하차도(도로)내    391     0      0     36    22    5.63
# 7    교차로횡단보도내    756     0      0     98    30    3.97
# 8          불명     10     0      0      0     1   10.00
# 9          기타   1517     0      0     75    29    1.91
# 10         합계  27063     4      0   1703   721     NaN

# %%
df1 = df1.fillna(0)
df1
# Out:
#          도로형태   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0        교차로안   7744     1      0    430   146    1.89
# 1       교차로부근   4004     0      0    206    80    2.00
# 2          터널    159     1      0     24     7    4.40
# 3          교량    237     0      0     27    13    5.49
# 4     기타(단일로)  12165     2      0    804   389    3.20
# 5       고가도로위     80     0      0      3     4    5.00
# 6   지하차도(도로)내    391     0      0     36    22    5.63
# 7    교차로횡단보도내    756     0      0     98    30    3.97
# 8          불명     10     0      0      0     1   10.00
# 9          기타   1517     0      0     75    29    1.91
# 10         합계  27063     4      0   1703   721    0.00

# %%
df2 = df1[['화물(건)', '사망자수']]
df2
# Out:
#     화물(건)  사망자수
# 0     430   146
# 1     206    80
# 2      24     7
# 3      27    13
# 4     804   389
# 5       3     4
# 6      36    22
# 7      98    30
# 8       0     1
# 9      75    29
# 10   1703   721

# %%
df_1 = df1["도로형태"]
df_2 = df1["발생건수"]
df_3 = df1["대형사고"]
df_4 = df1["화물(건)"]
df_5 = df1["사망자수"]
df_6 = df1["치사율(%)"]

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_3)
plt.title('대형사고')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_4)
plt.title('화물(건)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_5)
plt.title('사망자수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_6)
plt.title('치사량(%)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
p_1 = sns.distplot(df_2)
p_1.set_title("화물차 사고 발생 건수")
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, '화물차 사고 발생 건수')

# %%
sns.distplot(df_3)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='대형사고', ylabel='Density'>

# %%
sns.distplot(df_4)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='화물(건)', ylabel='Density'>

# %%
sns.distplot(df_5)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='사망자수', ylabel='Density'>

# %%
sns.distplot(df_6)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>

# %%
p = sns.lineplot(data = df2)
p.set_title("화물차 사망자 수 비교")
# Out:
# Text(0.5, 1.0, '화물차 사망자 수 비교')

# %%
fig, ax = plt.subplots(ncols=2, nrows=3, figsize=(20,20))

sns.distplot(df1['발생건수'], ax=ax[0,0])
sns.distplot(df1['대형사고'], ax=ax[0,1])
sns.distplot(df1['사망자수'], ax=ax[1,0])
sns.distplot(df1['치사율(%)'], ax=ax[1,1])
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.plot(df_1, df_4, 'o-', color='#C8C8FF', label='line01')
plt.plot(df_1, df_5, '^--g', linewidth=5, markeredgewidth=5, label='line02')

plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.title('사망자수/치사율(%)')

plt.show()
