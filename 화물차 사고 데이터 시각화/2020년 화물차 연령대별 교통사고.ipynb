# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib import rc 
rc('font', family='AppleGothic') 
plt.rcParams['axes.unicode_minus'] = False

# %%
df1 = pd.read_excel('2020년 화물차 연령대별 교통사고.xls')
df1
# Out:
#       연령대   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0  20대 미만     59     0      0      0     0    0.00
# 1     20대   1398     0      0     47    27    1.93
# 2     30대   2617     1      0    177    69    2.64
# 3     40대   5098     2      0    411   126    2.47
# 4     50대   8556     0      0    581   203    2.37
# 5  60대 이상   9319     1      0    487   296    3.18
# 6    알수없음     16     0      0      0     0    0.00
# 7      합계  27063     4      0   1703   721     NaN

# %%
df1 = df1.fillna(0)
df1
# Out:
#       연령대   발생건수  대형사고  여객(건)  화물(건)  사망자수  치사율(%)
# 0  20대 미만     59     0      0      0     0    0.00
# 1     20대   1398     0      0     47    27    1.93
# 2     30대   2617     1      0    177    69    2.64
# 3     40대   5098     2      0    411   126    2.47
# 4     50대   8556     0      0    581   203    2.37
# 5  60대 이상   9319     1      0    487   296    3.18
# 6    알수없음     16     0      0      0     0    0.00
# 7      합계  27063     4      0   1703   721    0.00

# %%
df2 = df1[['화물(건)', '사망자수']]
df2
# Out:
#    화물(건)  사망자수
# 0      0     0
# 1     47    27
# 2    177    69
# 3    411   126
# 4    581   203
# 5    487   296
# 6      0     0
# 7   1703   721

# %%
df_1 = df1["연령대"]
df_2 = df1["발생건수"]
df_3 = df1["대형사고"]
df_4 = df1["화물(건)"]
df_5 = df1["사망자수"]
df_6 = df1["치사율(%)"]

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_3)
plt.title('대형사고')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_4)
plt.title('화물(건)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_5)
plt.title('사망자수')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.bar(df_1, df_6)
plt.title('치사량(%)')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(df_1, df_2)
plt.title('발생건수')
plt.show()

# %%
p_1 = sns.distplot(df_2)
p_1.set_title("화물차 사고 발생 건수")
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, '화물차 사고 발생 건수')

# %%
sns.distplot(df_3)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='대형사고', ylabel='Density'>

# %%
sns.distplot(df_4)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='화물(건)', ylabel='Density'>

# %%
sns.distplot(df_5)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='사망자수', ylabel='Density'>

# %%
sns.distplot(df_6)
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>

# %%
p = sns.lineplot(data = df2)
p.set_title("화물차 사망자 수 비교")
# Out:
# Text(0.5, 1.0, '화물차 사망자 수 비교')

# %%
fig, ax = plt.subplots(ncols=2, nrows=3, figsize=(20,20))

sns.distplot(df1['발생건수'], ax=ax[0,0])
sns.distplot(df1['대형사고'], ax=ax[0,1])
sns.distplot(df1['사망자수'], ax=ax[1,0])
sns.distplot(df1['치사율(%)'], ax=ax[1,1])
# Out:
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/otaehun/opt/anaconda3/envs/dhxogns920/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='치사율(%)', ylabel='Density'>
